# %%
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")
submit = pd.read_csv("data/gender_submission.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# 使用info()函式觀察train以及test資料是否有空值，發現train的Age,Cabin,Embark有空值以及Test的Age, Fare, cabin有空值的情況，之後我們要想辦法來補這些空值。通常比賽能夠準確預測的關鍵都是在如何補空值。

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# 使用Describe來觀察train以及test的資料分布

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# 接下來由於要對整體資料做一些觀察，因此先將資料做合併
# Combine Train & Test Data

# %%
data = train.append(test)
data
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17    NaN          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19    NaN          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# 21   34.0          D56        S   13.0000
# 22   15.0          NaN        Q    8.0292
# 23   28.0           A6        S   35.5000
# 24    8.0          NaN        S   21.0750
# 25   38.0          NaN        S   31.3875
# 26    NaN          NaN        C    7.2250
# 27   19.0  C23 C25 C27        S  263.0000
# 28    NaN          NaN        Q    7.8792
# 29    NaN          NaN        S    7.8958
# ..    ...          ...      ...       ...
# 388  21.0          NaN        Q    7.7500
# 389   6.0          NaN        S   21.0750
# 390  23.0          B24        S   93.5000
# 391  51.0          D28        S   39.4000
# 392  13.0          NaN        S   20.2500
# 393  47.0          NaN        S   10.5000
# 394  29.0          NaN        S   22.0250
# 395  18.0          C31        S   60.0000
# 396  24.0          NaN        Q    7.2500
# 397  48.0          B41        C   79.2000
# 398  22.0          NaN        S    7.7750
# 399  31.0          NaN        Q    7.7333
# 400  30.0           C7        S  164.8667
# 401  38.0          NaN        S   21.0000
# 402  22.0          NaN        C   59.4000
# 403  17.0          NaN        S   47.1000
# 404  43.0          D40        C   27.7208
# 405  20.0          D38        C   13.8625
# 406  23.0          NaN        S   10.5000
# 407  50.0          C80        C  211.5000
# 408   NaN          NaN        Q    7.7208
# 409   3.0          NaN        S   13.7750
# 410   NaN          NaN        Q    7.7500
# 411  37.0          C78        Q   90.0000
# 412  28.0          NaN        S    7.7750
# 413   NaN          NaN        S    8.0500
# 414  39.0         C105        C  108.9000
# 415  38.5          NaN        S    7.2500
# 416   NaN          NaN        S    8.0500
# 417   NaN          NaN        C   22.3583
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# 5                                     Moran, Mr. James      0            6
# 6                              McCarthy, Mr. Timothy J      0            7
# 7                       Palsson, Master. Gosta Leonard      1            8
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2            9
# 9                  Nasser, Mrs. Nicholas (Adele Achem)      0           10
# 10                     Sandstrom, Miss. Marguerite Rut      1           11
# 11                            Bonnell, Miss. Elizabeth      0           12
# 12                      Saundercock, Mr. William Henry      0           13
# 13                         Andersson, Mr. Anders Johan      5           14
# 14                Vestrom, Miss. Hulda Amanda Adolfina      0           15
# 15                    Hewlett, Mrs. (Mary D Kingcome)       0           16
# 16                                Rice, Master. Eugene      1           17
# 17                        Williams, Mr. Charles Eugene      0           18
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...      0           19
# 19                             Masselmani, Mrs. Fatima      0           20
# 20                                Fynney, Mr. Joseph J      0           21
# 21                               Beesley, Mr. Lawrence      0           22
# 22                         McGowan, Miss. Anna "Annie"      0           23
# 23                        Sloper, Mr. William Thompson      0           24
# 24                       Palsson, Miss. Torborg Danira      1           25
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5           26
# 26                             Emir, Mr. Farred Chehab      0           27
# 27                      Fortune, Mr. Charles Alexander      2           28
# 28                       O'Dwyer, Miss. Ellen "Nellie"      0           29
# 29                                 Todoroff, Mr. Lalio      0           30
# ..                                                 ...    ...          ...
# 388                               Canavan, Mr. Patrick      0         1280
# 389                        Palsson, Master. Paul Folke      1         1281
# 390                         Payne, Mr. Vivian Ponsonby      0         1282
# 391     Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1         1283
# 392                      Abbott, Master. Eugene Joseph      2         1284
# 393                               Gilbert, Mr. William      0         1285
# 394                           Kink-Heilmann, Mr. Anton      1         1286
# 395     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)      0         1287
# 396                               Colbert, Mr. Patrick      0         1288
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1         1289
# 398                     Larsson-Rondberg, Mr. Edvard A      0         1290
# 399                           Conlon, Mr. Thomas Henry      0         1291
# 400                            Bonnell, Miss. Caroline      0         1292
# 401                                    Gale, Mr. Harry      0         1293
# 402                     Gibson, Miss. Dorothy Winifred      1         1294
# 403                             Carrau, Mr. Jose Pedro      0         1295
# 404                       Frauenthal, Mr. Isaac Gerald      0         1296
# 405       Nourney, Mr. Alfred (Baron von Drachstedt")"      0         1297
# 406                          Ware, Mr. William Jeffery      0         1298
# 407                         Widener, Mr. George Dunton      1         1299
# 408                    Riordan, Miss. Johanna Hannah""      0         1300
# 409                          Peacock, Miss. Treasteall      1         1301
# 410                             Naughton, Miss. Hannah      0         1302
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)      0         1303
# 412                     Henriksson, Miss. Jenny Lovisa      0         1304
# 413                                 Spector, Mr. Woolf      0         1305
# 414                       Oliva y Ocana, Dona. Fermina      0         1306
# 415                       Saether, Mr. Simon Sivertsen      0         1307
# 416                                Ware, Mr. Frederick      0         1308
# 417                           Peter, Master. Michael J      1         1309
#
#      Pclass     Sex  SibSp  Survived              Ticket
# 0         3    male      1       0.0           A/5 21171
# 1         1  female      1       1.0            PC 17599
# 2         3  female      0       1.0    STON/O2. 3101282
# 3         1  female      1       1.0              113803
# 4         3    male      0       0.0              373450
# 5         3    male      0       0.0              330877
# 6         1    male      0       0.0               17463
# 7         3    male      3       0.0              349909
# 8         3  female      0       1.0              347742
# 9         2  female      1       1.0              237736
# 10        3  female      1       1.0             PP 9549
# 11        1  female      0       1.0              113783
# 12        3    male      0       0.0           A/5. 2151
# 13        3    male      1       0.0              347082
# 14        3  female      0       0.0              350406
# 15        2  female      0       1.0              248706
# 16        3    male      4       0.0              382652
# 17        2    male      0       1.0              244373
# 18        3  female      1       0.0              345763
# 19        3  female      0       1.0                2649
# 20        2    male      0       0.0              239865
# 21        2    male      0       1.0              248698
# 22        3  female      0       1.0              330923
# 23        1    male      0       1.0              113788
# 24        3  female      3       0.0              349909
# 25        3  female      1       1.0              347077
# 26        3    male      0       0.0                2631
# 27        1    male      3       0.0               19950
# 28        3  female      0       1.0              330959
# 29        3    male      0       0.0              349216
# ..      ...     ...    ...       ...                 ...
# 388       3    male      0       NaN              364858
# 389       3    male      3       NaN              349909
# 390       1    male      0       NaN               12749
# 391       1  female      0       NaN            PC 17592
# 392       3    male      0       NaN           C.A. 2673
# 393       2    male      0       NaN          C.A. 30769
# 394       3    male      3       NaN              315153
# 395       1  female      1       NaN               13695
# 396       3    male      0       NaN              371109
# 397       1  female      1       NaN               13567
# 398       3    male      0       NaN              347065
# 399       3    male      0       NaN               21332
# 400       1  female      0       NaN               36928
# 401       2    male      1       NaN               28664
# 402       1  female      0       NaN              112378
# 403       1    male      0       NaN              113059
# 404       1    male      1       NaN               17765
# 405       2    male      0       NaN       SC/PARIS 2166
# 406       2    male      1       NaN               28666
# 407       1    male      1       NaN              113503
# 408       3  female      0       NaN              334915
# 409       3  female      1       NaN  SOTON/O.Q. 3101315
# 410       3  female      0       NaN              365237
# 411       1  female      1       NaN               19928
# 412       3  female      0       NaN              347086
# 413       3    male      0       NaN           A.5. 3236
# 414       1  female      0       NaN            PC 17758
# 415       3    male      0       NaN  SOTON/O.Q. 3101262
# 416       3    male      0       NaN              359309
# 417       3    male      1       NaN                2668
#
# [1309 rows x 12 columns]

# %% [markdown]
# 由於使用append合併之後會造成index重複問題，因此要將index重新設定

# %%
data.reset_index(inplace=True, drop=True)

# %% [markdown]
# Data Analysis

# %%
sns.countplot(data['Survived'])

# %%
sns.countplot(data['Pclass'], hue=data['Survived'])

# %%
sns.countplot(data['Sex'], hue=data['Survived'])

# %%
sns.countplot(data['Embarked'], hue=data['Survived'])

# %% [markdown]
# 年齡跟生存率的關係，可以發現的確年齡小的存活比例高出許多

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Age', kde=False)

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Fare', kde=False)

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Parch', kde=False)

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'SibSp', kde=False)

# %% [markdown]
# 經過一些反覆的測試把“父母＋小孩”加上“兄弟姊妹＋丈夫妻子”的數量變成一個新的欄位叫做家庭大小，在預測上會更為準確

# %%
data['Family_Size'] = data['Parch'] + data['SibSp']

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Family_Size', kde=False)

# %% [markdown]
# 特徵工程
# 接下來要來處理之前提到一些特徵，像是姓名這個欄位的資料就不能直接拿來用，但如果直接丟掉是一種資訊的浪費，因此我們稍微觀察一下名字這個欄位，可以發現名字的這個欄位有稱謂的資訊(Mr., Miss.) 我們可以利用這些資訊在未來更加提升預測的準確度

# %% [markdown]
# 將姓名的稱謂萃取出來，可以發現這些人的稱謂總共有’Mr’, ‘Mrs’, ‘Miss’, ‘Master’, ‘Don’, ‘Rev’, ‘Dr’, ‘Mme’, ‘Ms’, ‘Major’, ‘Lady’, ‘Sir’, ‘Mlle’, ‘Col’, ‘Capt’, ‘the Countess’, ‘Jonkheer’, ‘Dona’

# %%
data['Title1'] = data['Name'].str.split(", ", expand=True)[1]

# %%
data['Name'].str.split(", ", expand=True).head(3)
# Out:
#            0                                           1
# 0     Braund                             Mr. Owen Harris
# 1    Cumings  Mrs. John Bradley (Florence Briggs Thayer)
# 2  Heikkinen                                 Miss. Laina

# %%
data['Title1'].head(3)
# Out:
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# Name: Title1, dtype: object

# %%
data['Title1'] = data['Title1'].str.split(".", expand=True)[0]

# %%
data['Title1'].head(3)
# Out:
# 0      Mr
# 1     Mrs
# 2    Miss
# Name: Title1, dtype: object

# %%
data['Title1'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer', 'Dona'], dtype=object)

# %% [markdown]
# 將稱謂對性別、生存率、以及年齡做分析，發現一個有趣的地方，像是Master平均年齡只有五歲非常小，都是男生，並且生存機率有大約6成

# %%
pd.crosstab(data['Title1'],data['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col0 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col1 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col2 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col3 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col4 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col5 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col6 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col7 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col8 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col9 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col10 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col11 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col12 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col13 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col14 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col15 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col16 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col17 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col0 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col1 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col2 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col3 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col4 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col5 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col6 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col7 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col8 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col9 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col10 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col11 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col12 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col13 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col14 {
#             background-color:  #ffff66;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col15 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col16 {
#             background-color:  #008066;
#         }    #T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col17 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_807f1fac_44ba_11e8_a8da_a8667f01c00d" >
# <thead>    <tr>
#         <th class="index_name level0" >Title1</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Don</th>
#         <th class="col_heading level0 col3" >Dona</th>
#         <th class="col_heading level0 col4" >Dr</th>
#         <th class="col_heading level0 col5" >Jonkheer</th>
#         <th class="col_heading level0 col6" >Lady</th>
#         <th class="col_heading level0 col7" >Major</th>
#         <th class="col_heading level0 col8" >Master</th>
#         <th class="col_heading level0 col9" >Miss</th>
#         <th class="col_heading level0 col10" >Mlle</th>
#         <th class="col_heading level0 col11" >Mme</th>
#         <th class="col_heading level0 col12" >Mr</th>
#         <th class="col_heading level0 col13" >Mrs</th>
#         <th class="col_heading level0 col14" >Ms</th>
#         <th class="col_heading level0 col15" >Rev</th>
#         <th class="col_heading level0 col16" >Sir</th>
#         <th class="col_heading level0 col17" >the Countess</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_807f1fac_44ba_11e8_a8da_a8667f01c00dlevel0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col0" class="data row0 col0" >0</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col1" class="data row0 col1" >0</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col2" class="data row0 col2" >0</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col3" class="data row0 col3" >1</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col4" class="data row0 col4" >1</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col5" class="data row0 col5" >0</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col6" class="data row0 col6" >1</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col7" class="data row0 col7" >0</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col8" class="data row0 col8" >0</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col9" class="data row0 col9" >260</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col10" class="data row0 col10" >2</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col11" class="data row0 col11" >1</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col12" class="data row0 col12" >0</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col13" class="data row0 col13" >197</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col14" class="data row0 col14" >2</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col15" class="data row0 col15" >0</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col16" class="data row0 col16" >0</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow0_col17" class="data row0 col17" >1</td>
#     </tr>    <tr>
#         <th id="T_807f1fac_44ba_11e8_a8da_a8667f01c00dlevel0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col0" class="data row1 col0" >1</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col1" class="data row1 col1" >4</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a8667f01c00drow1_col2" class="data row1 col2" >1</td>
#         <td id="T_807f1fac_44ba_11e8_a8da_a86

# %%
pd.crosstab(data['Title1'],data['Survived']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col0 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col1 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col2 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col3 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col4 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col5 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col6 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col7 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col8 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col9 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col10 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col11 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col12 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col13 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col14 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col15 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col16 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col0 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col1 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col2 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col3 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col4 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col5 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col6 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col7 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col8 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col9 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col10 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col11 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col12 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col13 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col14 {
#             background-color:  #ffff66;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col15 {
#             background-color:  #008066;
#         }    #T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col16 {
#             background-color:  #008066;
#         }</style>
# <table id="T_b9769e36_44ba_11e8_8162_a8667f01c00d" >
# <thead>    <tr>
#         <th class="index_name level0" >Title1</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Don</th>
#         <th class="col_heading level0 col3" >Dr</th>
#         <th class="col_heading level0 col4" >Jonkheer</th>
#         <th class="col_heading level0 col5" >Lady</th>
#         <th class="col_heading level0 col6" >Major</th>
#         <th class="col_heading level0 col7" >Master</th>
#         <th class="col_heading level0 col8" >Miss</th>
#         <th class="col_heading level0 col9" >Mlle</th>
#         <th class="col_heading level0 col10" >Mme</th>
#         <th class="col_heading level0 col11" >Mr</th>
#         <th class="col_heading level0 col12" >Mrs</th>
#         <th class="col_heading level0 col13" >Ms</th>
#         <th class="col_heading level0 col14" >Rev</th>
#         <th class="col_heading level0 col15" >Sir</th>
#         <th class="col_heading level0 col16" >the Countess</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b9769e36_44ba_11e8_8162_a8667f01c00dlevel0_row0" class="row_heading level0 row0" >0.0</th>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col0" class="data row0 col0" >1</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col1" class="data row0 col1" >1</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col2" class="data row0 col2" >1</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col3" class="data row0 col3" >4</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col4" class="data row0 col4" >1</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col5" class="data row0 col5" >0</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col6" class="data row0 col6" >1</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col7" class="data row0 col7" >17</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col8" class="data row0 col8" >55</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col9" class="data row0 col9" >0</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col10" class="data row0 col10" >0</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col11" class="data row0 col11" >436</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col12" class="data row0 col12" >26</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col13" class="data row0 col13" >0</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col14" class="data row0 col14" >6</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col15" class="data row0 col15" >0</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow0_col16" class="data row0 col16" >0</td>
#     </tr>    <tr>
#         <th id="T_b9769e36_44ba_11e8_8162_a8667f01c00dlevel0_row1" class="row_heading level0 row1" >1.0</th>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col0" class="data row1 col0" >0</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col1" class="data row1 col1" >1</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col2" class="data row1 col2" >0</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col3" class="data row1 col3" >3</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col4" class="data row1 col4" >0</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col5" class="data row1 col5" >1</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00drow1_col6" class="data row1 col6" >1</td>
#         <td id="T_b9769e36_44ba_11e8_8162_a8667f01c00dr

# %%
data.groupby(['Title1'])['Age'].mean()
# Out:
# Title1
# Capt            70.000000
# Col             54.000000
# Don             40.000000
# Dona            39.000000
# Dr              43.571429
# Jonkheer        38.000000
# Lady            48.000000
# Major           48.500000
# Master           5.482642
# Miss            21.774238
# Mlle            24.000000
# Mme             24.000000
# Mr              32.252151
# Mrs             36.994118
# Ms              28.000000
# Rev             41.250000
# Sir             49.000000
# the Countess    33.000000
# Name: Age, dtype: float64

# %% [markdown]
# 若仔細觀察這些稱謂(’Mr’, ‘Mrs’, ‘Miss’, ‘Master’, ‘Don’, ‘Rev’, ‘Dr’, ‘Mme’, ‘Ms’, ‘Major’, ‘Lady’, ‘Sir’, ‘Mlle’, ‘Col’, ‘Capt’, ‘the Countess’, ‘Jonkheer’, ‘Dona’)會發現有些是稱謂的乘客非常少，如果我們只為了這些少數的乘客多了一個稱謂這樣對於機器學習的模型來說是一件不好的事情。因此我們把其中的稱謂做合併。

# %%
data['Title2'] = data['Title1'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','the Countess','Don','Sir','Capt','Jonkheer','Dona','Col','Rev'],['Miss','Mrs','Miss','Mr','Mr','Mrs','Mrs','Mr','Mr','Mr','Mr','Mrs','Mr','Mr'])

# %%
data['Title2'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master'], dtype=object)

# %%
pd.crosstab(data['Title2'],data['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_b8e90214_44bc_11e8_9db9_a8667f01c00drow0_col0 {
#             background-color:  #ffff66;
#         }    #T_b8e90214_44bc_11e8_9db9_a8667f01c00drow0_col1 {
#             background-color:  #008066;
#         }    #T_b8e90214_44bc_11e8_9db9_a8667f01c00drow0_col2 {
#             background-color:  #ffff66;
#         }    #T_b8e90214_44bc_11e8_9db9_a8667f01c00drow0_col3 {
#             background-color:  #008066;
#         }    #T_b8e90214_44bc_11e8_9db9_a8667f01c00drow1_col0 {
#             background-color:  #008066;
#         }    #T_b8e90214_44bc_11e8_9db9_a8667f01c00drow1_col1 {
#             background-color:  #ffff66;
#         }    #T_b8e90214_44bc_11e8_9db9_a8667f01c00drow1_col2 {
#             background-color:  #008066;
#         }    #T_b8e90214_44bc_11e8_9db9_a8667f01c00drow1_col3 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_b8e90214_44bc_11e8_9db9_a8667f01c00d" >
# <thead>    <tr>
#         <th class="index_name level0" >Title2</th>
#         <th class="col_heading level0 col0" >Master</th>
#         <th class="col_heading level0 col1" >Miss</th>
#         <th class="col_heading level0 col2" >Mr</th>
#         <th class="col_heading level0 col3" >Mrs</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b8e90214_44bc_11e8_9db9_a8667f01c00dlevel0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_b8e90214_44bc_11e8_9db9_a8667f01c00drow0_col0" class="data row0 col0" >0</td>
#         <td id="T_b8e90214_44bc_11e8_9db9_a8667f01c00drow0_col1" class="data row0 col1" >264</td>
#         <td id="T_b8e90214_44bc_11e8_9db9_a8667f01c00drow0_col2" class="data row0 col2" >1</td>
#         <td id="T_b8e90214_44bc_11e8_9db9_a8667f01c00drow0_col3" class="data row0 col3" >201</td>
#     </tr>    <tr>
#         <th id="T_b8e90214_44bc_11e8_9db9_a8667f01c00dlevel0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_b8e90214_44bc_11e8_9db9_a8667f01c00drow1_col0" class="data row1 col0" >61</td>
#         <td id="T_b8e90214_44bc_11e8_9db9_a8667f01c00drow1_col1" class="data row1 col1" >0</td>
#         <td id="T_b8e90214_44bc_11e8_9db9_a8667f01c00drow1_col2" class="data row1 col2" >782</td>
#         <td id="T_b8e90214_44bc_11e8_9db9_a8667f01c00drow1_col3" class="data row1 col3" >0</td>
#     </tr></tbody>
# </table>

# %%
pd.crosstab(data['Title2'],data['Survived']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow0_col0 {
#             background-color:  #ffff66;
#         }    #T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow0_col1 {
#             background-color:  #ffff66;
#         }    #T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow0_col2 {
#             background-color:  #008066;
#         }    #T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow0_col3 {
#             background-color:  #ffff66;
#         }    #T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow1_col0 {
#             background-color:  #008066;
#         }    #T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow1_col1 {
#             background-color:  #008066;
#         }    #T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow1_col2 {
#             background-color:  #ffff66;
#         }    #T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow1_col3 {
#             background-color:  #008066;
#         }</style>
# <table id="T_dc0e22c6_44bc_11e8_a842_a8667f01c00d" >
# <thead>    <tr>
#         <th class="index_name level0" >Title2</th>
#         <th class="col_heading level0 col0" >Master</th>
#         <th class="col_heading level0 col1" >Miss</th>
#         <th class="col_heading level0 col2" >Mr</th>
#         <th class="col_heading level0 col3" >Mrs</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_dc0e22c6_44bc_11e8_a842_a8667f01c00dlevel0_row0" class="row_heading level0 row0" >0.0</th>
#         <td id="T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow0_col0" class="data row0 col0" >17</td>
#         <td id="T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow0_col1" class="data row0 col1" >55</td>
#         <td id="T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow0_col2" class="data row0 col2" >451</td>
#         <td id="T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow0_col3" class="data row0 col3" >26</td>
#     </tr>    <tr>
#         <th id="T_dc0e22c6_44bc_11e8_a842_a8667f01c00dlevel0_row1" class="row_heading level0 row1" >1.0</th>
#         <td id="T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow1_col0" class="data row1 col0" >23</td>
#         <td id="T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow1_col1" class="data row1 col1" >130</td>
#         <td id="T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow1_col2" class="data row1 col2" >87</td>
#         <td id="T_dc0e22c6_44bc_11e8_a842_a8667f01c00drow1_col3" class="data row1 col3" >102</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# 再來把票號的資訊取出前面英文的部分，因為相同的英文代碼可能代表的是房間的位置，後面的號碼沒有意義所以省略，如果只有號碼的票號就用X來表示

# %%
data['Ticket_info'] = data['Ticket'].apply(lambda x : x.replace(".","").replace("/","").strip())

# %%
data['Ticket_info'].unique()
# Out:
# array(['A5 21171', 'PC 17599', 'STONO2 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A5 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'CA 24579', 'PC 17604', '113789', '2677',
#        'A5 2152', '345764', '2651', '7546', '11668', '349253',
#        'SCParis 2123', '330958', 'SCA4 23567', '370371', '14311', '2662',
#        '349237', '3101295', 'A4 39886', 'PC 17572', '2926', '113509',
#        '19947', 'CA 31026', '2697', 'CA 34651', 'CA 2144', '2669',
#        '113572', '36973', '347088', 'PC 17605', '2661', 'CA 29395',
#        'SP 3464', '3101281', '315151', 'CA 33111', 'SOC 14879', '2680',
#        '1601', '348123', '349208', '374746', '248738', '364516', '345767',
#        '345779', '330932', '113059', 'SOC 14885', '3101278', 'WC 6608',
#        'SOTONOQ 392086', '343275', '343276', '347466', 'WEP 5734',
#        'CA 2315', '364500', '374910', 'PC 17754', 'PC 17759', '231919',
#        '244367', '349245', '349215', '35281', '7540', '3101276', '349207',
#        '343120', '312991', '349249', '371110', '110465', '2665', '324669',
#        '4136', '2627', 'STONO 2 3101294', '370369', 'PC 17558', 'A4 54510',
#        '27267', '370372', 'C 17369', '2668', '347061', '349241',
#        'SOTONOQ 3101307', 'A5 3337', '228414', 'CA 29178', 'SCPARIS 2133',
#        '11752', '7534', 'PC 17593', '2678', '347081', 'STONO2 3101279',
#        '365222', '231945', 'CA 33112', '350043', '230080', '244310',
#        'SOP 1166', '113776', 'A5 11206', 'A5 851', 'Fa 265302', 'PC 17597',
#        '35851', 'SOTONOQ 392090', '315037', 'CA 2343', '371362',
#        'CA 33595', '347068', '315093', '363291', '113505', 'PC 17318',
#        '111240', 'STONO 2 3101280', '17764', '350404', '4133', 'PC 17595',
#        '250653', 'LINE', 'SCPARIS 2131', '230136', '315153', '113767',
#        '370365', '111428', '364849', '349247', '234604', '28424', '350046',
#        'PC 17610', '368703', '4579', '370370', '248747', '345770',
#        '3101264', '2628', 'A5 3540', '347054', '2699', '367231', '112277',
#        'SOTONOQ 3101311', 'FCC 13528', 'A5 21174', '250646', '367229',
#        '35273', 'STONO2 3101283', '243847', '11813', 'WC 14208',
#        'SOTONOQ 392089', '220367', '21440', '349234', '19943', 'PP 4348',
#        'SWPP 751', 'A5 21173', '236171', '347067', '237442', 'CA 29566',
#        'WC 6609', '26707', 'CA 31921', '28665', 'SCOW 1585', '367230',
#        'WC 14263', 'STONO 2 3101275', '2694', '19928', '347071', '250649',
#        '11751', '244252', '362316', '113514', 'A5 3336', '370129', '2650',
#        'PC 17585', '110152', 'PC 17755', '230433', '384461', '110413',
#        '112059', '382649', 'CA 17248', '347083', 'PC 17582', 'PC 17760',
#        '113798', '250644', 'PC 17596', '370375', '13502', '347073',
#        '239853', 'CA 2673', '336439', '347464', '345778', 'A5 10482',
#        '113056', '349239', '345774', '349206', '237798', '370373', '19877',
#        '11967', 'SCParis 2163', '349236', '349233', 'PC 17612', '2693',
#        '113781', '19988', '9234', '367226', '226593', 'A5 2466', '17421',
#        'PC 17758', 'PPP 3381', 'PC 17485', '11767', 'PC 17608', '250651',
#        '349243', 'FCC 13529', '347470', '29011', '36928', '16966',
#        'A5 21172', '349219', '234818', '345364', '28551', '111361',
#        '113043', 'PC 17611', '349225', '7598', '113784', '248740',
#        '244361', '229236', '248733', '31418', '386525', 'CA 37671',
#        '315088', '7267', '113510', '2695', '2647', '345783', '237671',
#        '330931', '330980', 'SCPARIS 2167', '2691', 'SOTONOQ 3101310',
#        'C 7076', '110813', '2626', '14313', 'PC 17477', '11765', '3101267',
#        '323951', 'C 7077', '113503', '2648', '347069', 'PC 17757', '2653',
#        'STONO 2 3101293', '349227', '27849', '367655', 'SC 1748', '113760',
#        '350034', '3101277', '350052', '350407', '28403', '244278',
#        '240929', 'STONO 2 3101289', '341826', '4137', '315096', '28664',
#        '347064', '29106', '312992', '349222', '394140', 'STONO 2 3101269',
#        '343095', '28220', '250652', '28228', '345773', '349254',
#        'A5 13032', '315082', '347080', 'A4 34244', '2003', '250655',
#        '364851', 'SOTONOQ 392078', '110564', '376564', 'SCAH 3085',
#        'STONO 2 3101274', '13507', 'CA 18723', '345769', '347076',
#        '230434', '65306', '33638', '113794', '2666', '113786', '65303',
#        '113051', '17453', 'A5 2817', '349240', '13509', '17464',
#        'FCC 13531', '371060', '19952', '364506', '111320', '234360',
#        'AS 2816', 'SOTONOQ 3101306', '113792', '36209', '323592', '315089',
#        'SCAH Basle 541', '7553', '31027', '3460', '350060', '3101298',
#        '239854', 'A5 3594', '4134', '11771', 'A5 18509', '65304',
#        'SOTONOQ 3101317', '113787', 'PC 17609', 'A4 45380', '36947',
#        'CA 6212', '350035', '315086', '364846', '330909', '4135', '26360',
#        '111427', 'C 4001', '382651', 'SOTONOQ 3101316', 'PC 17473',
#        'PC 17603', '349209', '36967', 'CA 34260', '226875', '349242',
#        '12749', '349252', '2624', '2700', '367232', 'WC 14258', 'PC 17483',
#        '3101296', '29104', '2641', '2690', '315084', '113050', 'PC 17761',
#        '364498', '13568', 'WEP 5735', '2908', '693', 'SCPARIS 2146',
#        '244358', '330979', '2620', '347085', '113807', '11755', '345572',
#        '372622', '349251', '218629', 'SOTONOQ 392082', 'SOTONOQ 392087',
#        'A4 48871', '349205', '2686', '350417', 'SWPP 752', '11769',
#        'PC 17474', '14312', 'A4 20589', '358585', '243880', '2689',
#        'STONO 2 3101286', '237789', '13049', '3411', '237565', '13567',
#        '14973', 'A5 3235', 'STONO 2 3101273', 'A5 3902', '364848',
#        'SCAH 29037', '248727', '2664', '349214', '113796', '364511',
#        '111426', '349910', '349246', '113804', 'SOTONOQ 3101305', '370377',
#        '364512', '220845', '31028', '2659', '11753', '350029', '54636',
#        '36963', '219533', '349224', '334912', '27042', '347743', '13214',
#        '112052', '237668', 'STONO 2 3101292', '350050', '349231', '13213',
#        'SOPP 751', 'CA 2314', '349221', '8475', '330919', '365226',
#        '349223', '29751', '2623', '5727', '349210', 'STONO 2 3101285',
#        '234686', '312993', 'A5 3536', '19996', '29750', 'FC 12750',
#        'CA 24580', '244270', '239856', '349912', '342826', '4138',
#        '330935', '6563', '349228', '350036', '24160', '17474', '349256',
#        '2672', '113800', '248731', '363592', '35852', '348121', 'PC 17475',
#        '36864', '350025', '223596', 'PC 17476', 'PC 17482', '113028',
#        '7545', '250647', '348124', '34218', '36568', '347062', '350048',
#        '12233', '250643', '113806', '315094', '36866', '236853',
#        'STONO2 3101271', '239855', '28425', '233639', '349201', '349218',
#        '16988', '376566', 'STONO 2 3101288', '250648', '113773', '335097',
#        '29103', '392096', '345780', '349204', '350042', '29108', '363294',
#        'SOTONO2 3101272', '2663', '347074', '112379', '364850', '8471',
#        '345781', '350047', 'SOPP 3', '2674', '29105', '347078', '383121',
#        '36865', '2687', '113501', 'WC 6607', 'SOTONOQ 3101312', '374887',
#        '3101265', '12460', 'PC 17600', '349203', '28213', '17465',
#        '349244', '2685', '2625', '347089', '347063', '112050', '347087',
#        '248723', '3474', '28206', '364499', '112058', 'STONO2 3101290',
#        'SCPARIS 2079', 'C 7075', '315098', '19972', '368323', '367228',
#        '2671', '347468', '2223', 'PC 17756', '315097', '392092', '11774',
#        'SOTONO2 3101287', '2683', '315090', 'CA 5547', '349213', '347060',
#        'PC 17592', '392091', '113055', '2629', '350026', '28134', '17466',
#        '233866', '236852', 'SCPARIS 2149', 'PC 17590', '345777', '349248',
#        '695', '345765', '2667', '349212', '349217', '349257', '7552',
#        'CASOTON 34068', 'SOTONOQ 392076', '211536', '112053', '111369',
#        '370376', '330911', '363272', '240276', '315154', '7538', '330972',
#        '2657', '349220', '694', '21228', '24065', '233734', '2692',
#        'STONO2 3101270', '2696', 'C 17368', 'PC 17598', '2698', '113054',
#        'CA 31029', '13236', '2682', '342712', '315087', '345768', '113778',
#        'SOTONOQ 3101263', '237249', 'STONO 2 3101291', 'PC 17594',
#        '370374', '13695', 'SCPARIS 2168', 'SCA3 2861', '349230', '348122',
#        '349232', '237216', '347090', '334914', 'FCC 13534', '330963',
#        '2543', '382653', '349211', '3101297', 'PC 17562', '359306',
#        '11770', '248744', '368702', '19924', '349238', '240261', '2660',
#        '330844', 'A4 31416', '364856', '347072', '345498', '376563',
#        '13905', '350033', 'STONO 2 3101268', '347471', 'A5 3338', '11778',
#        '365235', '347070', '330920', '383162', '3410', '248734', '237734',
#        '330968', 'PC 17531', '329944', '2681', '13050', '367227', '392095',
#        '368783', '350045', '211535', '342441', 'STONOQ 369943', '113780',
#        '2621', '349226', '350409', '2656', '248659', 'SOTONOQ 392083',
#        '17475', 'SCA4 23568', '113791', '349255', '3701', '350405',
#        'SOPP 752', '347469', '110489', 'SOTONOQ 3101315', '335432',
#        '220844', '343271', '237393', 'PC 17591', '17770', '7548',
#        'SOPP 251', '2670', '2673', '233478', '7935', '239059', 'SOPP 2',
#        'A4 48873', '28221', '111163', '235509', '347465', '347066',
#        'CA 31030', '65305', 'CA 34050', 'FC 12998', '9232', '28034',
#        'PC 17613', '349250', 'SOTONOQ 3101308', '347091', '113038',
#        '330924', '32302', 'SCPARIS 2148', '342684', 'WC 14266', '350053',
#        'PC 17606', '350054', '370368', '242963', '113795', '3101266',
#        '330971', '350416', '2679', '250650', '112377', '3470',
#        'SOTONO2 3101284', '13508', '7266', '345775', 'CA 42795',
#        'AQ4 3130', '363611', '28404', '345501', '350410', 'CA 34644',
#        '349235', '112051', 'CA 49867', 'A 2 39186', '315095', '368573',
#        '2676', 'SC 14888', 'CA 31352', 'WC 14260', '315085', '364859',
#        'A5 21175', 'SOTONOQ 3101314', '2655', 'A5 1478', 'PC 17607',
#        '382650', '2652', '345771', '349202', '113801', '347467', '347079',
#        '237735', '315092', '383123', '112901', '315091', '2658', 'LP 1588',
#        '368364', 'AQ3 30631', '28004', '350408', '347075', '2654',
#        '244368', '113790', 'SOTONOQ 3101309', '236854', 'PC 17580', '2684',
#        '349229', '110469', '244360', '2675', '2622', 'CA 15185', '350403',
#        '348125', '237670', '2688', '248726', 'FCC 13540', '113044', '1222',
#        '368402', '315083', '112378', 'SCPARIS 2147', '28133', '248746',
#        '315152', '29107', '680', '366713', '330910', 'SCPARIS 2159',
#        '349911', '244346', '364858', 'CA 30769', '371109', '347065',
#        '21332', '17765', 'SCPARIS 2166', '28666', '334915', '365237',
#        '347086', 'A5 3236', 'SOTONOQ 3101262', '359309'], dtype=object)

# %% [markdown]
# 由於登船港口(Embarked)只有遺漏少數，我們就直接補上出現次數最多的”S”，費用(Fare)也只有遺漏一筆，因此就直接補上平均值

# %%
data['Embarked'] = data['Embarked'].fillna('S')

# %%
data['Fare'] = data['Fare'].fillna(data['Fare'].mean())

# %% [markdown]
# 觀察Cabin的資料後，只取出最前面的英文字母，剩下的用NoCabin來表示

# %%
data['Cabin'].head(10)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %%
data['Cabin'] = data['Cabin'].apply(lambda x : str(x)[0] if not pd.isnull(x) else 'NoCabin')

# %%
data['Cabin'].unique()
# Out:
# array(['NoCabin', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
sns.countplot(data['Cabin'], hue=data['Survived'])

# %% [markdown]
# 將類別資料轉為整數

# %%
data['Sex'].astype('category').cat.codes
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# 5       1
# 6       1
# 7       1
# 8       0
# 9       0
# 10      0
# 11      0
# 12      1
# 13      1
# 14      0
# 15      0
# 16      1
# 17      1
# 18      0
# 19      0
# 20      1
# 21      1
# 22      0
# 23      1
# 24      0
# 25      0
# 26      1
# 27      1
# 28      0
# 29      1
#        ..
# 1279    1
# 1280    1
# 1281    1
# 1282    0
# 1283    1
# 1284    1
# 1285    1
# 1286    0
# 1287    1
# 1288    0
# 1289    1
# 1290    1
# 1291    0
# 1292    1
# 1293    0
# 1294    1
# 1295    1
# 1296    1
# 1297    1
# 1298    1
# 1299    0
# 1300    0
# 1301    0
# 1302    0
# 1303    0
# 1304    1
# 1305    0
# 1306    1
# 1307    1
# 1308    1
# Length: 1309, dtype: int8

# %%
data['Sex'] = data['Sex'].astype('category').cat.codes
data['Embarked'] = data['Embarked'].astype('category').cat.codes
data['Pclass'] = data['Pclass'].astype('category').cat.codes
data['Title1'] = data['Title1'].astype('category').cat.codes
data['Title2'] = data['Title2'].astype('category').cat.codes
data['Cabin'] = data['Cabin'].astype('category').cat.codes
data['Ticket_info'] = data['Ticket_info'].astype('category').cat.codes

# %% [markdown]
# 使用隨機森林來推測年齡

# %%
dataAgeNull = data[data["Age"].isnull()]
dataAgeNotNull = data[data["Age"].notnull()]
remove_outlier = dataAgeNotNull[(np.abs(dataAgeNotNull["Fare"]-dataAgeNotNull["Fare"].mean())>(4*dataAgeNotNull["Fare"].std()))|
                      (np.abs(dataAgeNotNull["Family_Size"]-dataAgeNotNull["Family_Size"].mean())>(4*dataAgeNotNull["Family_Size"].std()))                     
                     ]
rfModel_age = RandomForestRegressor(n_estimators=2000,random_state=42)
ageColumns = ['Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title1', 'Title2','Cabin','Ticket_info']
rfModel_age.fit(remove_outlier[ageColumns], remove_outlier["Age"])

ageNullValues = rfModel_age.predict(X= dataAgeNull[ageColumns])
dataAgeNull.loc[:,"Age"] = ageNullValues
data = dataAgeNull.append(dataAgeNotNull)
data.reset_index(inplace=True, drop=True)
# Out:
# /Users/ryan/anaconda3/envs/tensorflow/lib/python3.5/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
dataTrain = data[pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])
dataTest = data[~pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])

# %%
dataTrain.columns
# Out:
# Index(['Age', 'Cabin', 'Embarked', 'Fare', 'Name', 'Parch', 'PassengerId',
#        'Pclass', 'Sex', 'SibSp', 'Survived', 'Ticket', 'Family_Size', 'Title1',
#        'Title2', 'Ticket_info'],
#       dtype='object')

# %%
dataTrain = dataTrain[['Survived', 'Age', 'Embarked', 'Fare',  'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]
dataTest = dataTest[['Age', 'Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]

# %%
dataTrain
# Out:
#      Survived        Age  Embarked      Fare  Pclass  Sex  Family_Size  \
# 263       0.0  22.000000         2    7.2500       2    1            1
# 264       1.0  38.000000         0   71.2833       0    0            1
# 265       1.0  26.000000         2    7.9250       2    0            0
# 266       1.0  35.000000         2   53.1000       0    0            1
# 267       0.0  35.000000         2    8.0500       2    1            0
# 0         0.0  38.817129         1    8.4583       2    1            0
# 268       0.0  54.000000         2   51.8625       0    1            0
# 269       0.0   2.000000         2   21.0750       2    1            4
# 270       1.0  27.000000         2   11.1333       2    0            2
# 271       1.0  14.000000         0   30.0708       1    0            1
# 272       1.0   4.000000         2   16.7000       2    0            2
# 273       1.0  58.000000         2   26.5500       0    0            0
# 274       0.0  20.000000         2    8.0500       2    1            0
# 275       0.0  39.000000         2   31.2750       2    1            6
# 276       0.0  14.000000         2    7.8542       2    0            0
# 277       1.0  55.000000         2   16.0000       1    0            0
# 278       0.0   2.000000         1   29.1250       2    1            5
# 1         1.0  40.074155         2   13.0000       1    1            0
# 279       0.0  31.000000         2   18.0000       2    0            1
# 2         1.0  45.441708         0    7.2250       2    0            0
# 280       0.0  35.000000         2   26.0000       1    1            0
# 281       1.0  34.000000         2   13.0000       1    1            0
# 282       1.0  15.000000         1    8.0292       2    0            0
# 283       1.0  28.000000         2   35.5000       0    1            0
# 284       0.0   8.000000         2   21.0750       2    0            4
# 285       1.0  38.000000         2   31.3875       2    0            6
# 3         0.0  38.817129         0    7.2250       2    1            0
# 286       0.0  19.000000         2  263.0000       0    1            5
# 4         1.0  32.887501         1    7.8792       2    0            0
# 5         0.0  34.695131         2    7.8958       2    1            0
# ..        ...        ...       ...       ...     ...  ...          ...
# 951       0.0  21.000000         2   11.5000       1    1            1
# 952       1.0  48.000000         2   25.9292       0    0            0
# 173       0.0  15.476868         2   69.5500       2    0           10
# 953       0.0  24.000000         2   13.0000       1    1            0
# 954       1.0  42.000000         2   13.0000       1    0            0
# 955       1.0  27.000000         0   13.8583       1    0            1
# 956       0.0  31.000000         2   50.4958       0    1            0
# 174       0.0  37.175106         2    9.5000       2    1            0
# 957       1.0   4.000000         2   11.1333       2    1            2
# 958       0.0  26.000000         2    7.8958       2    1            0
# 959       1.0  47.000000         2   52.5542       0    0            2
# 960       0.0  33.000000         2    5.0000       0    1            0
# 961       0.0  47.000000         2    9.0000       2    1            0
# 962       1.0  28.000000         0   24.0000       1    0            1
# 963       1.0  15.000000         0    7.2250       2    0            0
# 964       0.0  20.000000         2    9.8458       2    1            0
# 965       0.0  19.000000         2    7.8958       2    1            0
# 175       0.0  34.695131         2    7.8958       2    1            0
# 966       1.0  56.000000         0   83.1583       0    0            1
# 967       1.0  25.000000         2   26.0000       1    0            1
# 968       0.0  33.000000         2    7.8958       2    1            0
# 969       0.0  22.000000         2   10.5167       2    0            0
# 970       0.0  28.000000         2   10.5000       1    1            0
# 971       0.0  25.000000         2    7.0500       2    1            0
# 972       0.0  39.000000         1   29.1250       2    0            5
# 973       0.0  27.000000         2   13.0000       1    1            0
# 974       1.0  19.000000         2   30.0000       0    0            0
# 176       0.0  17.554640         2   23.4500       2    0            3
# 975       1.0  26.000000         0   30.0000       0    1            0
# 976       0.0  32.000000         1    7.7500       2    1            0
#
#      Title2  Ticket_info  Cabin
# 263       2          719      7
# 264       3          815      2
# 265       1          913      7
# 266       3           65      2
# 267       2          649      7
# 0         2          373      7
# 268       2          109      4
# 269       0          541      7
# 270       3          477      7
# 271       3          174      7
# 272       1          838      6
# 273       1           50      2
# 274       2          724      7
# 275       2          459      7
# 276       1          566      7
# 277       3          204      7
# 278       0          659      7
# 1         2          201      7
# 279       3          417      7
# 2         3          243      7
# 280       2          182      7
# 281       2          203      3
# 282       1          379      7
# 283       2           54      0
# 284       1          541      7
# 285       3          454      7
# 3         2          238      7
# 286       2          123      2
# 4         1          385      7
# 5         2          499      7
# ..      ...          ...    ...
# 951       2          302      7
# 952       3          112      3
# 173       1          753      7
# 953       2          154      7
# 954       3          161      7
# 955       1          855      7
# 956       2          806      0
# 174       2          428      7
# 957       0          477      7
# 958       2          531      7
# 959       3           70      3
# 960       2          688      1
# 961       2          419      7
# 962       3          839      7
# 963       1          261      7
# 964       2          691      7
# 965       2          495      7
# 175       2          500      7
# 966       3           75      2
# 967       3          147      7
# 968       2          540      7
# 969       1          697      7
# 970       2          778      7
# 971       2          887      7
# 972       3          659      7
# 973       2          130      7
# 974       1           18      1
# 176       1          924      7
# 975       2           11      2
# 976       2          642      7
#
# [891 rows x 10 columns]

# %% [markdown]
# Model training

# %%
# rf = RandomForestClassifier(oob_score=True, random_state=1, n_jobs=-1)
# param_grid = { "criterion" : ["gini", "entropy"], "min_samples_leaf" : [1, 5, 10], "min_samples_split" : [2, 4, 10, 12, 16, 20], "n_estimators": [50, 100, 400, 700, 1000]}
# gs = GridSearchCV(estimator=rf, param_grid=param_grid, scoring='accuracy', cv=3, n_jobs=-1)

# gs = gs.fit(dataTrain.iloc[:, 1:], dataTrain.iloc[:, 0])

# print(gs.best_score_)
# print(gs.best_params_)

# %%
from sklearn.ensemble import RandomForestClassifier
 
rf = RandomForestClassifier(criterion='gini', 
                             n_estimators=1000,
                             min_samples_split=12,
                             min_samples_leaf=1,
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1) 

rf.fit(dataTrain.iloc[:, 1:], dataTrain.iloc[:, 0])
print("%.4f" % rf.oob_score_)
# Out:
# 0.8350

# %%
pd.concat((pd.DataFrame(dataTrain.iloc[:, 1:].columns, columns = ['variable']), 
           pd.DataFrame(rf.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)[:20]
# Out:
#       variable  importance
# 4          Sex    0.259645
# 7  Ticket_info    0.145259
# 6       Title2    0.142197
# 2         Fare    0.130699
# 0          Age    0.102880
# 3       Pclass    0.080083
# 5  Family_Size    0.061767
# 8        Cabin    0.057698
# 1     Embarked    0.019773

# %% [markdown]
# Submit

# %%
rf_res =  rf.predict(dataTest)
submit['Survived'] = rf_res
submit['Survived'] = submit['Survived'].astype(int)
submit.to_csv('submit.csv', index= False)

# %%
submit
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         0
# 19           911         1
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# 390         1282         1
# 391         1283         1
# 392         1284         1
# 393         1285         0
# 394         1286         0
# 395         1287         1
# 396         1288         0
# 397         1289         1
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         1
# 405         1297         0
# 406         1298         0
# 407         1299         0
# 408         1300         1
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 412         1304         0
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]
